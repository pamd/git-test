# %% [markdown]
# ipython test

# %%
get_ipython().run_line_magic('load_ext', 'rpy2.ipython')
# The line above is equivalen to:
# ipython> %load_ext rpy2.ipython

# %%
get_ipython().run_cell_magic('R', '', '1+2\n')  # output: 3
# The line above is equivalent to:
# ipython> %%R
#     ...  1+2

# %% [markdown]
# another test

# %%
print("foobar")
